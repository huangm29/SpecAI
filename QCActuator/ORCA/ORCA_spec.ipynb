# %% [markdown]
# # ORCA Spectroscopy Tools - Example
#
# This notebook demonstrates how to run various spectroscopy calculations on a single molecule using the enhanced ORCA tools.

# %%
# Import our quantum chemistry framework
from orca_tools import OrcaCalculator

# %% [markdown]
# ## 1. Setup ORCA Path
#
# First, define the path to your ORCA installation:

# %%
# Create a new calculator
calc = OrcaCalculator(config_file="config.yaml")

# %% [markdown]
# ## 2. Define Molecular Geometry
#
# Let's define the molecules for our examples:

# %%
# Formaldehyde
formaldehyde= """
  C          -0.00000007544128      0.00000007722154      0.02576945733573
  O           0.00000019009665     -0.00000002553588      1.23240550391654
  H           0.93816203542447     -0.00000002584283     -0.56908732489374
  H          -0.93816215007984     -0.00000002584283     -0.56908763635853
"""

# %%
# Cyclopropanol
Cyclopropanol= """
  C      1.231429   -0.226472   -0.084960
  C     -0.061893    0.507641    0.134338
  C     -1.358912   -0.147897    0.084831
  O     -0.902881    0.641038   -0.969176
  H      1.070541   -1.118875   -0.689778
  H      1.672013   -0.522768    0.869009
  H      1.946503    0.413187   -0.605194
  H      0.017832    1.411161    0.734623
  H     -1.417896   -1.212878   -0.118068
  H     -2.196737    0.255864    0.644375
"""

# %% [markdown]
# ## 3. Visualize Cyclopropanol
#
# Let's first visualize the Cyclopropanol molecule using py3Dmol:

# %%
# Visualize Cyclopropanol
calc.visualize_molecule(geometry=Cyclopropanol)
# Out:
# <div id="3dmolviewer_17424787718137176"  style="position: relative; width: 600px; height: 400px;">
#         <p id="3dmolwarning_17424787718137176" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17424787718137176 = null;
# var warn = document.getElementById("3dmolwarning_17424787718137176");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17424787718137176 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17424787718137176"),{backgroundColor:"white"});
# viewer_17424787718137176.zoomTo();
# 	viewer_17424787718137176.addModel("10\nGenerated by OrcaCalculator\nC      1.231429   -0.226472   -0.084960\n  C     -0.061893    0.507641    0.134338\n  C     -1.358912   -0.147897    0.084831\n  O     -0.902881    0.641038   -0.969176\n  H      1.070541   -1.118875   -0.689778\n  H      1.672013   -0.522768    0.869009\n  H      1.946503    0.413187   -0.605194\n  H      0.017832    1.411161    0.734623\n  H     -1.417896   -1.212878   -0.118068\n  H     -2.196737    0.255864    0.644375","xyz");
# 	viewer_17424787718137176.setStyle({"stick": {}});
# 	viewer_17424787718137176.zoomTo();
# viewer_17424787718137176.render();
# });
# </script>
# None

# %% [markdown]
# ## 4. Run UV-Vis Spectroscopy Calculation
#
# Let's run a UV-Vis absorption spectroscopy calculation on formaldehyde:

# %%
# Run UV-Vis calculation for formaldehyde
print("Running UV-Vis calculation...")
uv_spectrum = calc.run_spectroscopy(
    spec_type="UV", 
    geometry=formaldehyde
)
# Out:
# Running UV-Vis calculation...

# %% [markdown]
# ## 5. Run ECD Spectroscopy Calculation
#
# Let's run an ECD calculation on formaldehyde:

# %%
# Run ECD calculation for Cyclopropanol
print("Running ECD calculation...")
uv_spectrum = calc.run_spectroscopy(
    spec_type="ECD", 
    geometry=Cyclopropanol
)
# Out:
# Running ECD calculation...

# %% [markdown]
# ## 6. Run O K-edge X-ray Absorption Spectroscopy Calculation
#
# Let's run an XAS calculation on formaldehyde:

# %%
# Run O K-edge XAS calculation for formaldehyde
print("Running O K-edge XAS calculation...")
xas_spectrum = calc.run_spectroscopy(
    spec_type="XAS", 
    geometry=formaldehyde
)
# Out:
# Running O K-edge XAS calculation...

# %% [markdown]
# ## 7. Run IR Spectroscopy
#
# Now let's run an IR calculation on Formaldehyde (this will include OPT and FREQ):

# %%
# Run IR calculation for acetone (this will automatically add OPT and FREQ keywords)
print("Running IR calculation (with optimization)...")
ir_spectrum = calc.run_spectroscopy(
    spec_type="IR", 
    geometry=formaldehyde
    )
# Out:
# Running IR calculation (with optimization)...
# <div id="3dmolviewer_17424811456803925"  style="position: relative; width: 600px; height: 400px;">
#         <p id="3dmolwarning_17424811456803925" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17424811456803925 = null;
# var warn = document.getElementById("3dmolwarning_17424811456803925");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17424811456803925 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17424811456803925"),{backgroundColor:"white"});
# viewer_17424811456803925.zoomTo();
# 	viewer_17424811456803925.addModel("4\nCoordinates from ORCA-job /tmp/tmpfrme1upt/orca E -114.439027107375\n  C          -0.00000009142214      0.00000008983776      0.02576809160149\n  O           0.00000019558614     -0.00000002970186      1.23240541053076\n  H           0.93816827385997     -0.00000003006795     -0.56908659512860\n  H          -0.93816837802397     -0.00000003006795     -0.56908690700365\n","xyz");
# 	viewer_17424811456803925.setStyle({"stick": {}});
# 	viewer_17424811456803925.zoomTo();
# viewer_17424811456803925.render();
# });
# </script>
# None

# %% [markdown]
# ## 8. Run Raman Spectroscopy
#
# Now let's run a Rmaan calculation on Formaldehyde (this will include OPT and NUMFREQ):

# %%
# Run Raman calculation for acetone (this will automatically add OPT and FREQ keywords)
print("Running Raman calculation (with optimization)...")
raman_spectrum = calc.run_spectroscopy(
    spec_type="Raman", 
    geometry=formaldehyde
)
# Out:
# Running Raman calculation (with optimization)...
# <div id="3dmolviewer_17415804673710027"  style="position: relative; width: 600px; height: 400px;">
#         <p id="3dmolwarning_17415804673710027" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17415804673710027 = null;
# var warn = document.getElementById("3dmolwarning_17415804673710027");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17415804673710027 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17415804673710027"),{backgroundColor:"white"});
# viewer_17415804673710027.zoomTo();
# 	viewer_17415804673710027.addModel("4\nCoordinates from ORCA-job /tmp/tmpkb5qz_1i/orca E -114.439027107375\n  C          -0.00000009142214      0.00000008983776      0.02576809160149\n  O           0.00000019558614     -0.00000002970186      1.23240541053076\n  H           0.93816827385997     -0.00000003006795     -0.56908659512860\n  H          -0.93816837802397     -0.00000003006795     -0.56908690700365\n","xyz");
# 	viewer_17415804673710027.setStyle({"stick": {}});
# 	viewer_17415804673710027.zoomTo();
# viewer_17415804673710027.render();
# });
# </script>
# None

# %% [markdown]
# ## 9. Run VCD Spectroscopy
#
# Now let's run a VCD calculation on Cyclopropanol (this will include OPT and FREQ):

# %%
# Run VCD calculation for acetone (this will automatically add OPT and FREQ keywords)
print("Running VCD calculation (with optimization)...")
ir_spectrum = calc.run_spectroscopy(
    spec_type="VCD", 
    geometry=Cyclopropanol,
    basis="def2-SVP"
    )
# Out:
# Running VCD calculation (with optimization)...
# <div id="3dmolviewer_17415806073142018"  style="position: relative; width: 600px; height: 400px;">
#         <p id="3dmolwarning_17415806073142018" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17415806073142018 = null;
# var warn = document.getElementById("3dmolwarning_17415806073142018");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17415806073142018 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17415806073142018"),{backgroundColor:"white"});
# viewer_17415806073142018.zoomTo();
# 	viewer_17415806073142018.addModel("10\nCoordinates from ORCA-job /tmp/tmp7c68x0ai/orca E -192.847723731302\n  C           1.23664507112987     -0.22691926946775     -0.08421052680918\n  C          -0.05812598494554      0.51344130621993      0.13304004176470\n  C          -1.37045438506223     -0.14976095300040      0.08214422563837\n  O          -0.91449614762077      0.65717011836998     -0.99635833839207\n  H           1.07348009838463     -1.12968191129230     -0.69275598546807\n  H           1.68390922495063     -0.52517323590319      0.87882848667575\n  H           1.96458256427910      0.41258561985620     -0.61037279314390\n  H           0.02098440708147      1.42392422528306      0.74815842266342\n  H          -1.42230945571942     -1.22963958093155     -0.11793510117716\n  H          -2.21421639247774      0.25405468086602      0.65946156824816\n","xyz");
# 	viewer_17415806073142018.setStyle({"stick": {}});
# 	viewer_17415806073142018.zoomTo();
# viewer_17415806073142018.render();
# });
# </script>
# None

# %% [markdown]
# ## 10. Run NMR Spectroscopy
#
# Let's run an NMR calculation on formaldehyde:

# %%
# Run NMR calculation for acetone
print("Running NMR calculation...")
nmr_spectrum = calc.run_spectroscopy(
    spec_type="NMR", 
    geometry=formaldehyde
)
# Out:
# Running NMR calculation...

# %% [markdown]
# ## 11. Run EFEI Calculation
#
# Let's run an EFEI calculation on formaldehyde:

# %%
data = calc.run_efei_calculation(
    geometry=formaldehyde,
    efei_atoms=(2, 3),  # Field direction from atom 2 to atom 3
    efei_strength=6.0  # Field strength in atomic units
)
# Out:
# Running EFEI geometry optimization with field strength 6.0 between atoms (2, 3)
# Visualizing initial geometry...
# <div id="3dmolviewer_17415882630466645"  style="position: relative; width: 600px; height: 400px;">
#         <p id="3dmolwarning_17415882630466645" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17415882630466645 = null;
# var warn = document.getElementById("3dmolwarning_17415882630466645");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17415882630466645 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17415882630466645"),{backgroundColor:"white"});
# viewer_17415882630466645.zoomTo();
# 	viewer_17415882630466645.addModel("4\nGenerated by OrcaCalculator\nC          -0.00000007544128      0.00000007722154      0.02576945733573\n  O           0.00000019009665     -0.00000002553588      1.23240550391654\n  H           0.93816203542447     -0.00000002584283     -0.56908732489374\n  H          -0.93816215007984     -0.00000002584283     -0.56908763635853","xyz");
# 	viewer_17415882630466645.setStyle({"stick": {}});
# 	viewer_17415882630466645.zoomTo();
# viewer_17415882630466645.render();
# });
# </script>
# None
# Visualizing optimized geometry from /tmp/tmpt3w6lkpd/orca.xyz
# <div id="3dmolviewer_1741588293881513"  style="position: relative; width: 600px; height: 400px;">
#         <p id="3dmolwarning_1741588293881513" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_1741588293881513 = null;
# var warn = document.getElementById("3dmolwarning_1741588293881513");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1741588293881513 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1741588293881513"),{backgroundColor:"white"});
# viewer_1741588293881513.zoomTo();
# 	viewer_1741588293881513.addModel("4\nCoordinates from ORCA-job /tmp/tmpt3w6lkpd/orca E -114.391543481677\n  C           0.00000003570548     -0.00000002756561     -0.02384076910107\n  O          -0.00000000551535      0.00000000857939      1.17648419695313\n  H           1.22685395683720      0.00000000949309     -0.51632164192478\n  H          -1.22685398702733      0.00000000949313     -0.51632178592728\n","xyz");
# 	viewer_1741588293881513.setStyle({"stick": {}});
# 	viewer_1741588293881513.zoomTo();
# viewer_1741588293881513.render();
# });
# </script>
# None
